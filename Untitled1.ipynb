# %% [markdown]
# <a href="https://colab.research.google.com/github/khanous-ilyes/zmq/blob/khanous-ilyes-patch-1/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd /content
# !wget https://github.com/Harikrishnan6336/ShipORTruck-ImageClassifier/raw/main/ML_model/dataset.zip
# Out:
# --2023-01-06 13:28:45--  https://github.com/Harikrishnan6336/ShipORTruck-ImageClassifier/raw/main/ML_model/dataset.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Harikrishnan6336/ShipORTruck-ImageClassifier/main/ML_model/dataset.zip [following]
# --2023-01-06 13:28:45--  https://raw.githubusercontent.com/Harikrishnan6336/ShipORTruck-ImageClassifier/main/ML_model/dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23544102 (22M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>]  22.45M  --.-KB/s    in 0.07s
#
# 2023-01-06 13:28:47 (329 MB/s) - ‘dataset.zip’ saved [23544102/23544102]

# %%
# !ls
# Out:
# sample_data

# %%
# Out:
# dataset		model_ep14.pth	model_ep1.pth	model_ep25.pth	model_ep7.pth
# dataset.zip	model_ep15.pth	model_ep20.pth	model_ep2.pth	model_ep8.pth
# model_ep10.pth	model_ep16.pth	model_ep21.pth	model_ep3.pth	model_ep9.pth
# model_ep11.pth	model_ep17.pth	model_ep22.pth	model_ep4.pth	model.pth
# model_ep12.pth	model_ep18.pth	model_ep23.pth	model_ep5.pth	sample_data
# model_ep13.pth	model_ep19.pth	model_ep24.pth	model_ep6.pth

# %%
# Out:
# sample_data

# %%
# !unzip dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: dataset/train/truck/19147.png
#  extracting: dataset/train/truck/19175.png
#  extracting: dataset/train/truck/19191.png
#  extracting: dataset/train/truck/19194.png
#  extracting: dataset/train/truck/19200.png
#  extracting: dataset/train/truck/19204.png
#  extracting: dataset/train/truck/19244.png
#  extracting: dataset/train/truck/19249.png
#  extracting: dataset/train/truck/19261.png
#  extracting: dataset/train/truck/19267.png
#  extracting: dataset/train/truck/19280.png
#  extracting: dataset/train/truck/19290.png
#  extracting: dataset/train/truck/19291.png
#  extracting: dataset/train/truck/19300.png
#  extracting: dataset/train/truck/19303.png
#  extracting: dataset/train/truck/19312.png
#  extracting: dataset/train/truck/19324.png
#  extracting: dataset/train/truck/19334.png
#  extracting: dataset/train/truck/19354.png
#  extracting: dataset/train/truck/19356.png
#  extracting: dataset/train/truck/19357.png
#  extracting: dataset/train/truck/19366.png
#  extracting: dataset/train/truck/19368.png
#  extracting: dataset/train/truck/19370.png
#  extracting: dataset/train/truck/19378.png
#  extracting: dataset/train/truck/19381.png
#  extracting: dataset/train/truck/1941.png
#  extracting: dataset/train/truck/19411.png
#  extracting: dataset/train/truck/19412.png
#  extracting: dataset/train/truck/19425.png
#  extracting: dataset/train/truck/19430.png
#  extracting: dataset/train/truck/19433.png
#  extracting: dataset/train/truck/19443.png
#  extracting: dataset/train/truck/19470.png
#  extracting: dataset/train/truck/19471.png
#  extracting: dataset/train/truck/19475.png
#  extracting: dataset/train/truck/1948.png
#  extracting: dataset/train/truck/19487.png
#  extracting: dataset/train/truck/19489.png
#  extracting: dataset/train/truck/19499.png
#  extracting: dataset/train/truck/19506.png
#  extracting: dataset/train/truck/19518.png
#  extracting: dataset/train/truck/2846.png
#  extracting: dataset/train/truck/28460.png
#  extracting: dataset/train/truck/28484.png
#  extracting: dataset/train/truck/28496.png
#  extracting: dataset/train/truck/28512.png
#  extracting: dataset/train/truck/28515.png
#  extracting: dataset/train/truck/28528.png
# ...
#  extracting: dataset/valid/truck/6365.png
#  extracting: dataset/valid/truck/6366.png
#  extracting: dataset/valid/truck/6382.png
#  extracting: dataset/valid/truck/6385.png
#  extracting: dataset/valid/truck/6414.png
#  extracting: dataset/valid/truck/6427.png
#  extracting: dataset/valid/truck/6432.png
#  extracting: dataset/valid/truck/6439.png
#  extracting: dataset/valid/truck/644.png
#  extracting: dataset/valid/truck/6440.png
#  extracting: dataset/valid/truck/6458.png
#  extracting: dataset/valid/truck/6481.png
#  extracting: dataset/valid/truck/6517.png
#  extracting: dataset/valid/truck/6526.png
#  extracting: dataset/valid/truck/6532.png
#  extracting: dataset/valid/truck/6540.png
#  extracting: dataset/valid/truck/6547.png
#  extracting: dataset/valid/truck/6572.png
#  extracting: dataset/valid/truck/658.png
#  extracting: dataset/valid/truck/6580.png
#  extracting: dataset/valid/truck/6588.png
#  extracting: dataset/valid/truck/660.png
#  extracting: dataset/valid/truck/6611.png
#  extracting: dataset/valid/truck/6626.png
#  extracting: dataset/valid/truck/6644.png
#  extracting: dataset/valid/truck/6645.png
#  extracting: dataset/valid/truck/665.png
#  extracting: dataset/valid/truck/6658.png
#  extracting: dataset/valid/truck/6663.png
#  extracting: dataset/valid/truck/6667.png
#  extracting: dataset/valid/truck/667.png
#  extracting: dataset/valid/truck/6672.png
#  extracting: dataset/valid/truck/669.png
#  extracting: dataset/valid/truck/6693.png
#  extracting: dataset/valid/truck/6694.png
#  extracting: dataset/valid/truck/6706.png
#  extracting: dataset/valid/truck/6707.png
#  extracting: dataset/valid/truck/6709.png
#  extracting: dataset/valid/truck/6728.png
#  extracting: dataset/valid/truck/673.png
#  extracting: dataset/valid/truck/6747.png
#  extracting: dataset/valid/truck/6767.png
#  extracting: dataset/valid/truck/6785.png
#  extracting: dataset/valid/truck/68.png
#  extracting: dataset/valid/truck/680.png
#  extracting: dataset/valid/truck/6812.png
#  extracting: dataset/valid/truck/6835.png
#  extracting: dataset/valid/truck/6836.png
#  extracting: dataset/valid/truck/684.png
#  extracting: dataset/valid/truck/6846.png
#  extracting: dataset/valid/truck/6862.png
#  extracting: dataset/valid/truck/6871.png
#  extracting: dataset/valid/truck/6888.png
#  extracting: dataset/valid/truck/6891.png
#  extracting: dataset/valid/truck/6901.png
#  extracting: dataset/valid/truck/6904.png
#  extracting: dataset/valid/truck/6907.png
#  extracting: dataset/valid/truck/6935.png
#  extracting: dataset/valid/truck/6938.png
#  extracting: dataset/valid/truck/6952.png
#  extracting: dataset/valid/truck/6985.png
#  extracting: dataset/valid/truck/6992.png
#  extracting: dataset/valid/truck/6998.png
#  extracting: dataset/valid/truck/7011.png
#  extracting: dataset/valid/truck/704.png
#  extracting: dataset/valid/truck/7041.png
#  extracting: dataset/valid/truck/7043.png
#  extracting: dataset/valid/truck/707.png
#  extracting: dataset/valid/truck/7070.png
#  extracting: dataset/valid/truck/7072.png
#  extracting: dataset/valid/truck/7081.png
#  extracting: dataset/valid/truck/7112.png
#  extracting: dataset/valid/truck/7115.png
#  extracting: dataset/valid/truck/7128.png
#  extracting: dataset/valid/truck/7135.png
#  extracting: dataset/valid/truck/7168.png
#  extracting: dataset/valid/truck/7171.png
#  extracting: dataset/valid/truck/72.png
#  extracting: dataset/valid/truck/720.png
#  extracting: dataset/valid/truck/7200.png
#  extracting: dataset/valid/truck/7211.png
#  extracting: dataset/valid/truck/7241.png
#  extracting: dataset/valid/truck/7245.png
#  extracting: dataset/valid/truck/7246.png
#  extracting: dataset/valid/truck/7250.png
#  extracting: dataset/valid/truck/7263.png
#  extracting: dataset/valid/truck/7277.png
#  extracting: dataset/valid/truck/7293.png
#  extracting: dataset/valid/truck/7303.png
#  extracting: dataset/valid/truck/7338.png
#  extracting: dataset/valid/truck/7374.png
#  extracting: dataset/valid/truck/7392.png
#  extracting: dataset/valid/truck/7400.png
#  extracting: dataset/valid/truck/7415.png
#  extracting: dataset/valid/truck/7416.png
#  extracting: dataset/valid/truck/7419.png
#  extracting: dataset/valid/truck/7420.png
#  extracting: dataset/valid/truck/7422.png
#  extracting: dataset/valid/truck/7442.png
#  extracting: dataset/valid/truck/7454.png
#  extracting: dataset/valid/truck/7457.png
#  extracting: dataset/valid/truck/7458.png
#  extracting: dataset/valid/truck/7462.png
#  extracting: dataset/valid/truck/7472.png
#  extracting: dataset/valid/truck/7480.png
#  extracting: dataset/valid/truck/7495.png
#  extracting: dataset/valid/truck/750.png
#  extracting: dataset/valid/truck/7513.png
#  extracting: dataset/valid/truck/7527.png
#  extracting: dataset/valid/truck/7555.png
#  extracting: dataset/valid/truck/7557.png
#  extracting: dataset/valid/truck/757.png
#  extracting: dataset/valid/truck/7571.png
#  extracting: dataset/valid/truck/7572.png
#  extracting: dataset/valid/truck/7584.png
#  extracting: dataset/valid/truck/7595.png
#  extracting: dataset/valid/truck/7609.png
#  extracting: dataset/valid/truck/7629.png
#  extracting: dataset/valid/truck/7630.png
#  extracting: dataset/valid/truck/764.png
#  extracting: dataset/valid/truck/7646.png
#  extracting: dataset/valid/truck/7653.png
#  extracting: dataset/valid/truck/7658.png
#  extracting: dataset/valid/truck/7688.png
#  extracting: dataset/valid/truck/769.png
#  extracting: dataset/valid/truck/7692.png
#  extracting: dataset/valid/truck/7693.png
#  extracting: dataset/valid/truck/7695.png
#  extracting: dataset/valid/truck/7699.png
#  extracting: dataset/valid/truck/77.png
#  extracting: dataset/valid/truck/770.png
#  extracting: dataset/valid/truck/7704.png
#  extracting: dataset/valid/truck/7705.png
#  extracting: dataset/valid/truck/7709.png
#  extracting: dataset/valid/truck/7712.png
#  extracting: dataset/valid/truck/7747.png
#  extracting: dataset/valid/truck/7753.png
#  extracting: dataset/valid/truck/7760.png
#  extracting: dataset/valid/truck/7761.png
#  extracting: dataset/valid/truck/7764.png
#  extracting: dataset/valid/truck/7765.png
#  extracting: dataset/valid/truck/7787.png
#  extracting: dataset/valid/truck/7792.png
#  extracting: dataset/valid/truck/7794.png
#  extracting: dataset/valid/truck/7839.png
#  extracting: dataset/valid/truck/7855.png
#  extracting: dataset/valid/truck/7857.png
#  extracting: dataset/valid/truck/7892.png
#  extracting: dataset/valid/truck/7893.png
#  extracting: dataset/valid/truck/7903.png
#  extracting: dataset/valid/truck/7905.png
#  extracting: dataset/valid/truck/7918.png
#  extracting: dataset/valid/truck/792.png
#  extracting: dataset/valid/truck/7921.png
#  extracting: dataset/valid/truck/7944.png
#  extracting: dataset/valid/truck/7945.png
#  extracting: dataset/valid/truck/7961.png
#  extracting: dataset/valid/truck/7981.png
#  extracting: dataset/valid/truck/799.png
#  extracting: dataset/valid/truck/7991.png
#  extracting: dataset/valid/truck/8004.png
#  extracting: dataset/valid/truck/8013.png
#  extracting: dataset/valid/truck/8062.png
#  extracting: dataset/valid/truck/8076.png
#  extracting: dataset/valid/truck/8088.png
#  extracting: dataset/valid/truck/8090.png
#  extracting: dataset/valid/truck/8104.png
#  extracting: dataset/valid/truck/8111.png
#  extracting: dataset/valid/truck/8126.png
#  extracting: dataset/valid/truck/8127.png
#  extracting: dataset/valid/truck/8142.png
#  extracting: dataset/valid/truck/8146.png
#  extracting: dataset/valid/truck/8147.png
#  extracting: dataset/valid/truck/8153.png
#  extracting: dataset/valid/truck/8160.png
#  extracting: dataset/valid/truck/8214.png
#  extracting: dataset/valid/truck/8227.png
#  extracting: dataset/valid/truck/8246.png
#  extracting: dataset/valid/truck/8282.png
#  extracting: dataset/valid/truck/829.png
#  extracting: dataset/valid/truck/8291.png
#  extracting: dataset/valid/truck/8296.png
#  extracting: dataset/valid/truck/8299.png
#  extracting: dataset/valid/truck/8304.png
#  extracting: dataset/valid/truck/8309.png
#  extracting: dataset/valid/truck/8311.png
#  extracting: dataset/valid/truck/8318.png
#  extracting: dataset/valid/truck/8319.png
#  extracting: dataset/valid/truck/8324.png
#  extracting: dataset/valid/truck/8328.png
#  extracting: dataset/valid/truck/8355.png
#  extracting: dataset/valid/truck/8365.png
#  extracting: dataset/valid/truck/8389.png
#  extracting: dataset/valid/truck/8395.png
#  extracting: dataset/valid/truck/8403.png
#  extracting: dataset/valid/truck/8414.png
#  extracting: dataset/valid/truck/8417.png
#  extracting: dataset/valid/truck/8429.png
#  extracting: dataset/valid/truck/8436.png
#  extracting: dataset/valid/truck/8440.png
#  extracting: dataset/valid/truck/8442.png
#  extracting: dataset/valid/truck/8449.png
#  extracting: dataset/valid/truck/8459.png
#  extracting: dataset/valid/truck/8471.png
#  extracting: dataset/valid/truck/8480.png
#  extracting: dataset/valid/truck/8494.png
#  extracting: dataset/valid/truck/8502.png
#  extracting: dataset/valid/truck/8506.png
#  extracting: dataset/valid/truck/8507.png
#  extracting: dataset/valid/truck/8511.png
#  extracting: dataset/valid/truck/8518.png
#  extracting: dataset/valid/truck/8533.png
#  extracting: dataset/valid/truck/8540.png
#  extracting: dataset/valid/truck/8561.png
#  extracting: dataset/valid/truck/8562.png
#  extracting: dataset/valid/truck/8566.png
#  extracting: dataset/valid/truck/8568.png
#  extracting: dataset/valid/truck/8569.png
#  extracting: dataset/valid/truck/8576.png
#  extracting: dataset/valid/truck/8588.png
#  extracting: dataset/valid/truck/8603.png
#  extracting: dataset/valid/truck/8614.png
#  extracting: dataset/valid/truck/8633.png
#  extracting: dataset/valid/truck/8645.png
#  extracting: dataset/valid/truck/8651.png
#  extracting: dataset/valid/truck/8659.png
#  extracting: dataset/valid/truck/8671.png
#  extracting: dataset/valid/truck/8674.png
#  extracting: dataset/valid/truck/868.png
#  extracting: dataset/valid/truck/8717.png
#  extracting: dataset/valid/truck/8726.png
#  extracting: dataset/valid/truck/8728.png
#  extracting: dataset/valid/truck/8729.png
#  extracting: dataset/valid/truck/8744.png
#  extracting: dataset/valid/truck/8750.png
#  extracting: dataset/valid/truck/8755.png
#  extracting: dataset/valid/truck/8759.png
#  extracting: dataset/valid/truck/8763.png
#  extracting: dataset/valid/truck/8774.png
#  extracting: dataset/valid/truck/878.png
#  extracting: dataset/valid/truck/8784.png
#  extracting: dataset/valid/truck/8789.png
#  extracting: dataset/valid/truck/8808.png
#  extracting: dataset/valid/truck/8812.png
#  extracting: dataset/valid/truck/882.png
#  extracting: dataset/valid/truck/8822.png
#  extracting: dataset/valid/truck/8827.png
#  extracting: dataset/valid/truck/8836.png
#  extracting: dataset/valid/truck/8838.png
#  extracting: dataset/valid/truck/8839.png
#  extracting: dataset/valid/truck/884.png
#  extracting: dataset/valid/truck/8841.png
#  extracting: dataset/valid/truck/8842.png
#  extracting: dataset/valid/truck/885.png
#  extracting: dataset/valid/truck/8851.png
#  extracting: dataset/valid/truck/887.png
#  extracting: dataset/valid/truck/8887.png
#  extracting: dataset/valid/truck/8897.png
#  extracting: dataset/valid/truck/89.png
#  extracting: dataset/valid/truck/891.png
#  extracting: dataset/valid/truck/8934.png
#  extracting: dataset/valid/truck/8946.png
#  extracting: dataset/valid/truck/8952.png
#  extracting: dataset/valid/truck/8956.png
#  extracting: dataset/valid/truck/8960.png
#  extracting: dataset/valid/truck/8976.png
#  extracting: dataset/valid/truck/8993.png
#  extracting: dataset/valid/truck/9000.png
#  extracting: dataset/valid/truck/9004.png
#  extracting: dataset/valid/truck/901.png
#  extracting: dataset/valid/truck/9026.png
#  extracting: dataset/valid/truck/9027.png
#  extracting: dataset/valid/truck/9028.png
#  extracting: dataset/valid/truck/9029.png
#  extracting: dataset/valid/truck/9037.png
#  extracting: dataset/valid/truck/9047.png
#  extracting: dataset/valid/truck/9066.png
#  extracting: dataset/valid/truck/9092.png
#  extracting: dataset/valid/truck/9098.png
#  extracting: dataset/valid/truck/9107.png
#  extracting: dataset/valid/truck/9116.png
#  extracting: dataset/valid/truck/9140.png
#  extracting: dataset/valid/truck/9144.png
#  extracting: dataset/valid/truck/9147.png
#  extracting: dataset/valid/truck/916.png
#  extracting: dataset/valid/truck/9170.png
#  extracting: dataset/valid/truck/9178.png
#  extracting: dataset/valid/truck/9188.png
#  extracting: dataset/valid/truck/9196.png
#  extracting: dataset/valid/truck/9212.png
#  extracting: dataset/valid/truck/9214.png
#  extracting: dataset/valid/truck/9219.png
#  extracting: dataset/valid/truck/9230.png
#  extracting: dataset/valid/truck/9243.png
#  extracting: dataset/valid/truck/9245.png
#  extracting: dataset/valid/truck/9262.png
#  extracting: dataset/valid/truck/9271.png
#  extracting: dataset/valid/truck/9278.png
#  extracting: dataset/valid/truck/9303.png
#  extracting: dataset/valid/truck/9309.png
#  extracting: dataset/valid/truck/9337.png
#  extracting: dataset/valid/truck/9341.png
#  extracting: dataset/valid/truck/9359.png
#  extracting: dataset/valid/truck/9377.png
#  extracting: dataset/valid/truck/9383.png
#  extracting: dataset/valid/truck/9397.png
#  extracting: dataset/valid/truck/9413.png
#  extracting: dataset/valid/truck/9420.png
#  extracting: dataset/valid/truck/9426.png
#  extracting: dataset/valid/truck/9433.png
#  extracting: dataset/valid/truck/9435.png
#  extracting: dataset/valid/truck/9448.png
#  extracting: dataset/valid/truck/9462.png
#  extracting: dataset/valid/truck/9467.png
#  extracting: dataset/valid/truck/9488.png
#  extracting: dataset/valid/truck/9502.png
#  extracting: dataset/valid/truck/951.png
#  extracting: dataset/valid/truck/9512.png
#  extracting: dataset/valid/truck/9514.png
#  extracting: dataset/valid/truck/9533.png
#  extracting: dataset/valid/truck/954.png
#  extracting: dataset/valid/truck/9542.png
#  extracting: dataset/valid/truck/9558.png
#  extracting: dataset/valid/truck/9574.png
#  extracting: dataset/valid/truck/9599.png
#  extracting: dataset/valid/truck/9602.png
#  extracting: dataset/valid/truck/9607.png
#  extracting: dataset/valid/truck/9609.png
#  extracting: dataset/valid/truck/9627.png
#  extracting: dataset/valid/truck/965.png
#  extracting: dataset/valid/truck/9653.png
#  extracting: dataset/valid/truck/9655.png
#  extracting: dataset/valid/truck/9674.png
#  extracting: dataset/valid/truck/9677.png
#  extracting: dataset/valid/truck/9684.png
#  extracting: dataset/valid/truck/9702.png
#  extracting: dataset/valid/truck/9705.png
#  extracting: dataset/valid/truck/9706.png
#  extracting: dataset/valid/truck/971.png
#  extracting: dataset/valid/truck/9716.png
#  extracting: dataset/valid/truck/9722.png
#  extracting: dataset/valid/truck/9729.png
#  extracting: dataset/valid/truck/9740.png
#  extracting: dataset/valid/truck/9788.png
#  extracting: dataset/valid/truck/9808.png
#  extracting: dataset/valid/truck/9811.png
#  extracting: dataset/valid/truck/9813.png
#  extracting: dataset/valid/truck/9826.png
#  extracting: dataset/valid/truck/9844.png
#  extracting: dataset/valid/truck/9870.png
#  extracting: dataset/valid/truck/9881.png
#  extracting: dataset/valid/truck/9887.png
#  extracting: dataset/valid/truck/9894.png
#  extracting: dataset/valid/truck/9903.png
#  extracting: dataset/valid/truck/9912.png
#  extracting: dataset/valid/truck/9920.png
#  extracting: dataset/valid/truck/9937.png
#  extracting: dataset/valid/truck/9948.png
#  extracting: dataset/valid/truck/9956.png
#  extracting: dataset/valid/truck/9960.png
#  extracting: dataset/valid/truck/9962.png
#  extracting: dataset/valid/truck/9972.png
#  extracting: dataset/valid/truck/9991.png
#  extracting: dataset/valid/truck/9997.png

# %%
from PIL import Image
import torch
import torchvision
from torchvision.transforms import ToTensor
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import os
import pickle

# %%
     

class Dataset:
    def __init__(self, dir_name):
        self.dir_name = dir_name
        self.labels,self.images = self.load_data()
        
    # To load images and labels for dataloader
    def load_data(self):
        labels={}
        images = {}
        # Composes Resize transform, Here resize transforms the input image to size (256, 256)
        resize = transforms.Compose([transforms.Resize((256,256))])
        main_dir = os.listdir(os.path.join("dataset",self.dir_name))
        count = 0
        # traversing through the categories/directories(here SHIP and TRUCK) in the main directory
        for i,dir in enumerate(main_dir):
            images_list = os.listdir(os.path.join("dataset",self.dir_name,dir))
            # traversing through the images in each directory/category
            local_cnt = 0
            for img in images_list: 
                labels[count] = i
                img_path = os.path.join("dataset",self.dir_name,dir,img)
                image = Image.open(img_path)
                image = ToTensor()(image)
                images[count] = resize(image)
                count += 1
                local_cnt += 1
        return labels,images
      
    def __len__(self):
        return len(self.labels)
    
    # To return x,y values in each iteration over dataloader as batches.
    def __getitem__(self, idx):
        return (
            self.images[idx],
            self.labels[idx],
        )

# %%
dataset = Dataset("train")

validdataset = Dataset("valid")

# %%
print(validdataset.__len__())
# Out:
# 2000

# %%
# Model Architecture
class Network(nn.Module):
    def __init__(self):
        super(Network,self).__init__()

        # Convolutional layers
        self.conv1= nn.Conv2d(in_channels=3,out_channels=6,kernel_size=5)
        self.conv2= nn.Conv2d(in_channels=6,out_channels=12,kernel_size=5)
        self.conv3= nn.Conv2d(in_channels=12,out_channels=24,kernel_size=5)
        self.conv4= nn.Conv2d(in_channels=24,out_channels=48,kernel_size=5)
        
        # Fully Connected layers
        self.fc1 = nn.Linear(in_features=48*12*12,out_features=240)
        self.fc2 = nn.Linear(in_features=240,out_features=120)
        self.out = nn.Linear(in_features=120,out_features=2)
        
        
    def forward(self,t):
        t = t
        
        t=self.conv1(t)
        t=F.relu(t)
        t=F.max_pool2d(t,kernel_size = 2, stride = 2)
        
        
        t=self.conv2(t)
        t=F.relu(t)
        t=F.max_pool2d(t,kernel_size = 2, stride = 2)

        t=self.conv3(t)
        t=F.relu(t)
        t=F.max_pool2d(t,kernel_size = 2, stride = 2)

        t=self.conv4(t)
        t=F.relu(t)
        t=F.max_pool2d(t,kernel_size = 2, stride = 2)
        
        t=t.reshape(-1,48*12*12)
        t=self.fc1(t)
        t=F.relu(t)
        t=self.fc2(t)
        t=F.relu(t)
        
        t=self.out(t)
        
        return t

# %%
model = Network()
print("Model structure: ", model, "\n\n")
# Out:
# Model structure:  Network(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(12, 24, kernel_size=(5, 5), stride=(1, 1))
#   (conv4): Conv2d(24, 48, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=6912, out_features=240, bias=True)
#   (fc2): Linear(in_features=240, out_features=120, bias=True)
#   (out): Linear(in_features=120, out_features=2, bias=True)
# )

# %%
def train(dataset,validdataset, model):
    model.train()

    # dataloader in pytorch to load validation and train dataset
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=64,shuffle=True)
    valdataloader = torch.utils.data.DataLoader(validdataset, batch_size=32,shuffle=True)

    # Defining the loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    num_of_epochs = 3
    epochs = []
    losses = []
    accuracy = []
    for epoch in range(num_of_epochs):
        cnt = 0
        tot_loss = 0
        for batch, (x, y) in enumerate(dataloader):
            # Sets the gradients of all optimized tensors to zero
            optimizer.zero_grad()
            y_pred = model(x)
            # Compute loss (here CrossEntropyLoss)
            loss = F.cross_entropy(y_pred,y)

            loss.backward()
            optimizer.step()

        size = len(valdataloader.dataset)
        correct = 0
        for batch, (x, y) in enumerate(valdataloader):
            # Sets the gradients of all optimized tensors to zero
            optimizer.zero_grad()
            with torch.no_grad():
                y_pred = model(x)
                # Compute loss (here CrossEntropyLoss)
                loss = F.cross_entropy(y_pred,y)
                
            correct += (y_pred.argmax(1) == y).type(torch.float).sum().item()
            tot_loss+=loss.item()

        # accuracy.append((correct*100))
        epochs.append(epoch)
        losses.append(tot_loss)
        correct /= size
        accuracy.append(correct*100)
        print("Epoch ",epoch," Accuracy ",(100*correct),"% loss: ",tot_loss)
        # Save model after each epoch, so that we can choose the best model, later
        torch.save(model.state_dict(), "model_ep"+str(epoch+1)+".pth")

        # Plot a Validation Accuracy vs Epochs graph 
    plt.plot(epochs, accuracy, color='green', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=8) 
    plt.xlabel('epochs ---->',color='m',fontsize='xx-large' ) 
    plt.ylabel('Val Accuracy (in %) ------>',color='m',fontsize='xx-large') 
    axes = plt.gca()        # 'gca' - get current axes
    axes.set_facecolor('c') #'c' - cyan (color name)
    axes.tick_params(axis='y', which='both', colors='tomato')
    axes.tick_params(axis='x', which='both', colors='#20ff14')
    plt.title("Validation Accuracy vs Epoch",color='m',fontsize='xx-large')

# %%
train(dataset,validdataset, model)
# Out:
# Epoch  0  Accuracy  74.95 % loss:  32.31178179383278
# Epoch  1  Accuracy  86.0 % loss:  20.646179243922234
# Epoch  2  Accuracy  88.4 % loss:  17.75042822957039
# Epoch  3  Accuracy  90.14999999999999 % loss:  15.322709575295448
# Epoch  4  Accuracy  91.60000000000001 % loss:  13.022111807018518

# %%
torch.save(model.state_dict(), "model.pth")

# %%
def predict(img_path):
    image = Image.open(img_path)
    image = ToTensor()(image)
    resize = transforms.Compose([transforms.Resize((256,256))])
    y_result = model(resize(image).unsqueeze(0))
    result_idx = y_result.argmax(dim=1)
    for key,value in resize.items():
        if(value==result_idx):
            print(value)
            break

# %%
import matplotlib.pyplot as plt
import numpy as np
classes=('truck','ship')
batch_size=4
# Function to show the images
def imageshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# Function to test the model with a batch of images and show the labels predictions
def testBatch():
    # get batch of images from the test DataLoader  
    images, labels = validdataset[700]
    #labels=str(labels)
    # show all images as one image grid
    imageshow(torchvision.utils.make_grid(images))
   
    # Show the real labels on the screen 
    print('Real labels: ', ' '.join('%5s' % classes[labels]))
  
    # Let's see what if the model identifiers the  labels of those example
    outputs = model(images)
    
    # We got the probability for every 10 labels. The highest (max) probability should be correct label
    _, predicted = torch.max(outputs, 1)
    
    # Let's show the predicted labels on the screen to compare with the real ones
    print('Predicted: ', ' '.join('%5s' % classes[predicted[j]] 
                              for j in range(1)))

# %%
model = Network()
path = "model.pth"
model.load_state_dict(torch.load(path))

# Test with batch of images
testBatch()
# Out:
# Real labels:  t r u c k
# Predicted:  truck

# %%
def display_img(img,label):
   
    plt.imshow(img.permute(1,2,0))

#display the first image in the dataset
display_img(*dataset[700])
